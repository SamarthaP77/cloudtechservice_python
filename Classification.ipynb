# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\gaura\Desktop\CloudTech\cloudservice_python\Machine Learning\Admission.csv")
df
# Out:
#     gmat  gpa  work_experience  admitted
# 0    780  4.0                3         1
# 1    750  3.9                4         1
# 2    690  3.3                3         0
# 3    710  3.7                5         1
# 4    680  3.9                4         0
# 5    730  3.7                6         1
# 6    690  2.3                1         0
# 7    720  3.3                4         1
# 8    740  3.3                5         1
# 9    690  1.7                1         0
# 10   610  2.7                3         0
# 11   690  3.7                5         1
# 12   710  3.7                6         1
# 13   680  3.3                4         0
# 14   770  3.3                3         1
# 15   610  3.0                1         0
# 16   580  2.7                4         0
# 17   650  3.7                6         1
# 18   540  2.7                2         0
# 19   590  2.3                3         0
# 20   620  3.3                2         1
# 21   600  2.0                1         0
# ...

# %%
X = df[['gmat', 'gpa' , 'work_experience']]
y = df['admitted']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
y_test
# Out:
# 22    0
# 20    1
# 25    1
# 4     0
# 10    0
# 15    0
# 28    1
# 11    1
# 18    0
# 29    1
# Name: admitted, dtype: int64

# %%
X_test
# Out:
#     gmat  gpa  work_experience
# 22   550  2.3                4
# 20   620  3.3                2
# 25   670  3.3                6
# 4    680  3.9                4
# 10   610  2.7                3
# 15   610  3.0                1
# 28   650  3.7                6
# 11   690  3.7                5
# 18   540  2.7                2
# 29   660  3.3                5

# %%
logistic_regression = LogisticRegression() #Creating logistic regression calssification

# %%
logistic_regression.fit(X_train,y_train) #fit the model with data
# Out:
# LogisticRegression()

# %%
y_pred=logistic_regression.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 1, 1, 0, 0, 1, 1, 0, 1], dtype=int64)

# %%
X_test
# Out:
#     gmat  gpa  work_experience
# 22   550  2.3                4
# 20   620  3.3                2
# 25   670  3.3                6
# 4    680  3.9                4
# 10   610  2.7                3
# 15   610  3.0                1
# 28   650  3.7                6
# 11   690  3.7                5
# 18   540  2.7                2
# 29   660  3.3                5

# %%
#import the metrics class

from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[4, 1],
#        [1, 4]], dtype=int64)

# %%
import seaborn as sn
# %matplotlib inline

# %%
sn.heatmap(pd.DataFrame(cnf_matrix))
plt.title('Confusion matrix')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8

# %%
adm = logistic_regression.predict([[690,3.5,3]])
print(adm)
# Out:
# [0]
# C:\Users\gaura\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
