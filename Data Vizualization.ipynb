# %%
Data Visualization

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4]
y=[12,22,7,34]
plt.show(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y,color='blue')
plt.xlabel("Serial Number")
plt.ylabel("Distribution")
plt.title("My first line chart")
plt.show()

# %%
#A scatter plot with 1000 dots
import numpy as np
import matplotlib.pyplot as plt
x = np.random.random(100)
y = np.linspace(1,50,100)
plt.scatter(x,y,color='red')
plt.show()

# %%
#Bar chat/Plot
from matplotlib import pyplot as plt
Subjects = ["Mathematics","Science","Hindi","English"]
Marks = [90,98,78,100]
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("My first bar plot")
plt.bar(Subjects,Marks)
plt.show()

# %%
#Example of horizontal bar
from matplotlib import pyplot as plt
Subjects = ["Mathematics","Science","Hindi","English"]
Marks = [90,98,78,100]
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("My first bar plot")
plt.barh(Subjects,Marks)
plt.show()

# %%
plt.bar([1,3,5,7,9],[5,2,7,8,2],label="Example one")
plt.bar([2,4,6,8,10],[8,6,2,5,6],label="Example two", color='g')
plt.legend()
plt.xlabel('bar number')
plt.ylabel('bar height')

plt.title('epic graph\Another graph')
plt.show()

# %%
#Creating a scatter plot using a data from csv file:
import pandas as pd
df = pd.read_csv("homeprices.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
x=df['area']
y=df['price']
plt.scatter(x,y)
plt.show()

# %%
#Creating a bar plot using a data from csv file:
import pandas as pd
df = pd.read_csv("homeprices.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
x=df['area']
y=df['price']
plt.bar(x,y)
plt.show()

# %%
HISTOGRAM

# %%
import numpy as np
from matplotlib import pyplot as plt
a=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a, bins = [0,25,50,75,100])
plt.show()

# %%
#Generating random integers in histogram
x = np.random.randint(1,100,100)
print(x)
plt.hist(x, bins=10)
plt.show()
# Out:
# [65  2  4 87 98 62  9  5 72 51 90 18 63  6 73 84  3 16 91 37 42 80 61 57
#  11 34  6 46 76 13 39 30 92 32 73 13 30 61 22  9 22 28 43 18 88 26 34 13
#  88 62 32 79 97 70 44 18 82 53 20 15 24 87 57 71 12 67 92 61 63 10 35 60
#  38 63 41 22 18 59 74 73 83 80 58 46 43 92 60 72  8 25 91 77 27 50 49 96
#  59 98 81 91]

# %%
#Reading data from a csv file
import pandas as pd
df = pd.read_csv('homeprices.csv')
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
area = df['area']
price = df['price']
legend = ['length', 'money']
plt.hist([area, price], color = ['black', 'yellow'])
plt.show()

# %%
Area chart/Plot

# %%
x=[1,2,3,4]
y=[12,20,6,14]
plt.fill_between(x,y)
plt.show()

# %%
Pie Chart

# %%
cars = ['Audi','bmw','ford','tesla','Mercedez']
data = [10,23,45,67,89]
plt.pie(data, labels = cars)
plt.show()

# %%
BOXPLOT

# %%
from matplotlib import pyplot as plt
data1=[100,234,124,567,678]
plt.boxplot(data1)
plt.show()

# %%
#Contour plots
import numpy as np
from matplotlib import pyplot as plt
#Generatig 100 numbers from -3.0 to 3.0
xlist = np.linspace (-3.0,3.0,100)
ylist = np.linspace (-3.0,3.0,100)
X,Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + Y**2)
plt.contourf(X,Y,Z)
plt.show()
